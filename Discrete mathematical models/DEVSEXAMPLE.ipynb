# %%
# -*- coding: cp1251 -*-
from DEVS import *
import random
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

maxAngents = 100
arrivalRateMin = 1
arrivalRateMax = 8
service_xk = np.arange(13, 19) + 1
service_pk = (0.1, 0.2, 0.3, 0.25, 0.1, 0.05)
seed = 42
custm = stats.rv_discrete(name="custm", values=(service_xk, service_pk), seed = seed)

avg_queue_time = {}
total_time = {}
waited_custs = {}
server_dynamic = {}

# %%
# QUEUE TYPE: General queue
queue_type = "General queue"

custm = stats.rv_discrete(name="custm", values=(service_xk, service_pk), seed = seed)

# ---- Customer Statistics ----
class customerStat:
    def __init__(self):
        self.id = -1
        self.arrivalTime = -1
        self.serviceTime = -1
        self.interArrivalTime = 0
        self.serviceBegins = -1
        self.waitingTimeInQueue = 0
        self.serviceEnds = -1
        self.timeInSystem = -1
        self.idleTimeOfServer = 0


# ---- Arrival Event ----
class ArrivalEvent:
    def __init__(self):
        self.eTime = 0.0

    def Execute(self):
        customer = customerStat()
        customer.id = DEVS.newId
        customer.arrivalTime = self.eTime
        if len(DEVS.stats) > 0:
            customer.interArrivalTime = (
                customer.arrivalTime - DEVS.stats[-1].arrivalTime
            )

        print("Time %d" % self.eTime, " Arrival Event of agent {0}".format(customer.id))
        if DEVS.newId < maxAngents - 1:
            NextArrival = ArrivalEvent()
            NextArrival.eTime = self.eTime + random.randint(
                arrivalRateMin, arrivalRateMax
            )
            DEVS.EQ.AddEvent(NextArrival)

        server = -1
        # Server choosing policy
        for i in range(len(DEVS.serverIdle)):
            if DEVS.serverIdle[i] == True:
                server = i
                break

        # server is Free
        if server != -1:
            DEVS.serverIdle[server] = False
            print("server %d is Busy" % server)
            Service = ServiceEvent(server)
            serviceTime = custm.rvs()
            customer.serviceTime = serviceTime
            customer.serviceBegins = self.eTime  # current time
            Service.eTime = self.eTime + serviceTime
            Service.id = customer.id
            DEVS.EQ.AddEvent(Service)
        # server is Busy
        else:
            # increase waiting line
            DEVS.customerQueue.append(customer.id)
            print("customerQueue = %d" % len(DEVS.customerQueue))

        DEVS.newId = DEVS.newId + 1
        DEVS.stats.append(customer)


# ---- Service (END) Event ----
class ServiceEvent:
    def __init__(self, n):
        self.eTime = 0.0
        self.number = n
        self.id = 0

    def Execute(self):
        ind = [i for i, val in enumerate(DEVS.stats) if val.id == self.id][0]
        DEVS.stats[ind].serviceEnds = self.eTime
        DEVS.stats[ind].timeInSystem = (
            DEVS.stats[ind].serviceEnds - DEVS.stats[ind].arrivalTime
        )
        DEVS.stats[ind].waitingTimeInQueue = (
            DEVS.stats[ind].serviceBegins - DEVS.stats[ind].arrivalTime
        )  # 0 without queue
        DEVS.stats[ind].idleTimeOfServer = (
            DEVS.stats[ind].serviceBegins - DEVS.lastServedTime
        )

        print(
            "Time %d" % self.eTime,
            "Server %d service finished" % self.number,
        )
        if len(DEVS.customerQueue) > 0:
            qid = DEVS.customerQueue.pop(0)
            qind = [i for i, val in enumerate(DEVS.stats) if val.id == qid][0]
            Service = ServiceEvent(self.number)
            serviceTime = custm.rvs()
            Service.eTime = self.eTime + serviceTime
            Service.id = qid
            DEVS.stats[qind].serviceBegins = self.eTime
            DEVS.stats[qind].serviceTime = serviceTime
            DEVS.EQ.AddEvent(Service)
            print("take new customer from the queue")
        else:
            DEVS.serverIdle[self.number] = True
            print("server %d is Idle (do nothing)" % self.number)

        DEVS.lastServedTime = self.eTime


# run simulation
AE = ArrivalEvent()
DEVS.EQ.AddEvent(AE)

number_of_servers = 4
# simulation attributes
DEVS.customerQueue = []
DEVS.stats = []
DEVS.newId = 0
DEVS.serverIdle = [True for i in range(number_of_servers)]
DEVS.lastServedTime = 0  # for Idle time

# --- SIMULATION ---
while DEVS.EQ.QueueSize() > 0:
    DEVS.ProcessNextEvent()

# --- STATISTICS ---

#  --- store all in file  ---
f = open("output.csv", "w")
f.write(
    "Id;Interarrival Time;Arrival Time;Service Time;Time Service Begins;Waiting time in Queue;Time Service Ends;Time Customer Spends in System;Idle time of Server\n"
)
for s in DEVS.stats:
    f.write(
        "{0};{1};{2};{3};{4};{5};{6};{7};{8}\n".format(
            s.id,
            s.interArrivalTime,
            s.arrivalTime,
            s.serviceTime,
            s.serviceBegins,
            s.waitingTimeInQueue,
            s.serviceEnds,
            s.timeInSystem,
            s.idleTimeOfServer,
        )
    )
f.close()

# 1) Average waiting time in queue
avTimeInQueue = sum([x.waitingTimeInQueue for x in DEVS.stats]) / len(DEVS.stats)
print("\nAverage waiting time: {0:.2f}".format(avTimeInQueue))

# 2) Probability that a customer has to wait
probToWait = len([x for x in DEVS.stats if x.waitingTimeInQueue > 0]) / len(DEVS.stats)
print("\nProbability that a customer has to wait: {0:.2f}".format(probToWait))

# 3) Probability of an Idle server
probIdle = sum([x.idleTimeOfServer for x in DEVS.stats]) / DEVS.GlobalTime
print("\nProbability of an Idle server: {0:.2f}".format(probIdle))

# 4) Average service time (theoretical 3.2)
avServiceTime = sum([x.serviceTime for x in DEVS.stats]) / len(DEVS.stats)
print("\nAverage service time: {0:.2f}".format(avServiceTime))

# 5) Average time between arrivals (theoretical 4.5)
avTimeBetwArr = sum([x.interArrivalTime for x in DEVS.stats]) / (len(DEVS.stats) - 1)
print("\nAverage time between arrivals: {0:.2f}".format(avTimeBetwArr))

# 6) Average waiting time for those who wait
numOfCustWhoWait = len([x for x in DEVS.stats if x.waitingTimeInQueue > 0])
avTimeWhoWait = sum([x.waitingTimeInQueue for x in DEVS.stats]) / numOfCustWhoWait
print("\nAverage waiting time for those who wait: {0:.2f}".format(avTimeWhoWait))

# 7) Average time a customer spends in the system
avTimeInTheSystem1 = sum([x.timeInSystem for x in DEVS.stats]) / len(DEVS.stats)
print(
    "\nAverage time a customer spends in the system: {0:.2f}".format(avTimeInTheSystem1)
)

avTimeInTheSystem2 = avTimeInQueue + avServiceTime
print(
    "\nAverage time a customer spends in the system (alternative): {0:.2f}".format(
        avTimeInTheSystem2
    )
)


total_time[queue_type] = DEVS.lastServedTime
avg_queue_time[queue_type] = avTimeInQueue
waited_custs[queue_type] = numOfCustWhoWait
# Out:
# Time 0  Arrival Event of agent 0
# server 0 is Busy
# Time 2  Arrival Event of agent 1
# server 1 is Busy
# Time 4  Arrival Event of agent 2
# server 2 is Busy
# Time 6  Arrival Event of agent 3
# server 3 is Busy
# Time 8  Arrival Event of agent 4
# customerQueue = 1
# Time 13  Arrival Event of agent 5
# customerQueue = 2
# Time 16 Server 0 service finished
# take new customer from the queue
# Time 21 Server 1 service finished
# take new customer from the queue
# Time 21 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 21  Arrival Event of agent 6
# server 2 is Busy
# Time 22 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 26  Arrival Event of agent 7
# server 3 is Busy
# Time 31 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 33  Arrival Event of agent 8
# server 0 is Busy
# Time 35 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 36 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 38  Arrival Event of agent 9
# server 1 is Busy
# Time 43  Arrival Event of agent 10
# server 2 is Busy
# Time 44 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 48  Arrival Event of agent 11
# server 3 is Busy
# Time 50 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 53  Arrival Event of agent 12
# server 0 is Busy
# Time 55 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 57 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 61  Arrival Event of agent 13
# server 1 is Busy
# Time 67 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 67  Arrival Event of agent 14
# server 2 is Busy
# Time 70 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 73  Arrival Event of agent 15
# server 0 is Busy
# Time 76 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 77  Arrival Event of agent 16
# server 1 is Busy
# Time 79  Arrival Event of agent 17
# server 3 is Busy
# Time 82 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 82  Arrival Event of agent 18
# server 2 is Busy
# Time 88 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 88  Arrival Event of agent 19
# server 0 is Busy
# Time 89  Arrival Event of agent 20
# customerQueue = 1
# Time 90  Arrival Event of agent 21
# customerQueue = 2
# Time 93 Server 1 service finished
# take new customer from the queue
# Time 95 Server 3 service finished
# take new customer from the queue
# Time 95  Arrival Event of agent 22
# customerQueue = 1
# Time 98 Server 2 service finished
# take new customer from the queue
# Time 102  Arrival Event of agent 23
# customerQueue = 1
# Time 103 Server 0 service finished
# take new customer from the queue
# Time 110 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 110 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 110  Arrival Event of agent 24
# server 1 is Busy
# Time 113 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 114  Arrival Event of agent 25
# server 2 is Busy
# Time 116  Arrival Event of agent 26
# server 3 is Busy
# Time 119 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 122  Arrival Event of agent 27
# server 0 is Busy
# Time 126 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 127  Arrival Event of agent 28
# server 1 is Busy
# Time 131 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 131 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 134  Arrival Event of agent 29
# server 2 is Busy
# Time 135  Arrival Event of agent 30
# server 3 is Busy
# Time 138 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 139  Arrival Event of agent 31
# server 0 is Busy
# Time 142  Arrival Event of agent 32
# customerQueue = 1
# Time 143 Server 1 service finished
# take new customer from the queue
# Time 148 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 149  Arrival Event of agent 33
# server 2 is Busy
# Time 152 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 153  Arrival Event of agent 34
# server 3 is Busy
# Time 154 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 157 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 161  Arrival Event of agent 35
# server 0 is Busy
# Time 167 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 169  Arrival Event of agent 36
# server 1 is Busy
# Time 170  Arrival Event of agent 37
# server 2 is Busy
# Time 172 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 174  Arrival Event of agent 38
# server 3 is Busy
# Time 178 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 180  Arrival Event of agent 39
# server 0 is Busy
# Time 184 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 185 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 187  Arrival Event of agent 40
# server 1 is Busy
# Time 191 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 193  Arrival Event of agent 41
# server 2 is Busy
# Time 196 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 200  Arrival Event of agent 42
# server 0 is Busy
# Time 201  Arrival Event of agent 43
# server 3 is Busy
# Time 202 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 203  Arrival Event of agent 44
# server 1 is Busy
# Time 209 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 211  Arrival Event of agent 45
# server 2 is Busy
# Time 214 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 218 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 218  Arrival Event of agent 46
# server 0 is Busy
# Time 219 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 222  Arrival Event of agent 47
# server 1 is Busy
# Time 228 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 229  Arrival Event of agent 48
# server 2 is Busy
# Time 230  Arrival Event of agent 49
# server 3 is Busy
# Time 234 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 237  Arrival Event of agent 50
# server 0 is Busy
# Time 238 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 242  Arrival Event of agent 51
# server 1 is Busy
# Time 245 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 245 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 250  Arrival Event of agent 52
# server 2 is Busy
# Time 256 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 257  Arrival Event of agent 53
# server 0 is Busy
# Time 258  Arrival Event of agent 54
# server 3 is Busy
# Time 259 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 259  Arrival Event of agent 55
# server 1 is Busy
# Time 267  Arrival Event of agent 56
# customerQueue = 1
# Time 268 Server 2 service finished
# take new customer from the queue
# Time 274 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 274  Arrival Event of agent 57
# server 3 is Busy
# Time 275 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 277 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 277  Arrival Event of agent 58
# server 0 is Busy
# Time 282 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 283  Arrival Event of agent 59
# server 1 is Busy
# Time 289 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 291 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 291  Arrival Event of agent 60
# server 0 is Busy
# Time 298  Arrival Event of agent 61
# server 2 is Busy
# Time 299 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 299  Arrival Event of agent 62
# server 1 is Busy
# Time 302  Arrival Event of agent 63
# server 3 is Busy
# Time 303  Arrival Event of agent 64
# customerQueue = 1
# Time 307 Server 0 service finished
# take new customer from the queue
# Time 309  Arrival Event of agent 65
# customerQueue = 1
# Time 310  Arrival Event of agent 66
# customerQueue = 2
# Time 313 Server 2 service finished
# take new customer from the queue
# Time 316 Server 1 service finished
# take new customer from the queue
# Time 318 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 318  Arrival Event of agent 67
# server 3 is Busy
# Time 322 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 323  Arrival Event of agent 68
# server 0 is Busy
# Time 326  Arrival Event of agent 69
# customerQueue = 1
# Time 329 Server 2 service finished
# take new customer from the queue
# Time 331 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 331  Arrival Event of agent 70
# server 1 is Busy
# Time 333  Arrival Event of agent 71
# customerQueue = 1
# Time 335 Server 3 service finished
# take new customer from the queue
# Time 337 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 340  Arrival Event of agent 72
# server 0 is Busy
# Time 341  Arrival Event of agent 73
# customerQueue = 1
# Time 348 Server 2 service finished
# take new customer from the queue
# Time 348 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 348  Arrival Event of agent 74
# server 1 is Busy
# Time 350 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 351  Arrival Event of agent 75
# server 3 is Busy
# Time 354 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 358  Arrival Event of agent 76
# server 0 is Busy
# Time 365 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 365 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 366  Arrival Event of agent 77
# server 1 is Busy
# Time 367  Arrival Event of agent 78
# server 2 is Busy
# Time 368 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 370  Arrival Event of agent 79
# server 3 is Busy
# Time 375 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 375  Arrival Event of agent 80
# server 0 is Busy
# Time 377  Arrival Event of agent 81
# customerQueue = 1
# Time 378  Arrival Event of agent 82
# customerQueue = 2
# Time 380 Server 1 service finished
# take new customer from the queue
# Time 383 Server 2 service finished
# take new customer from the queue
# Time 384  Arrival Event of agent 83
# customerQueue = 1
# Time 385 Server 3 service finished
# take new customer from the queue
# Time 389  Arrival Event of agent 84
# customerQueue = 1
# Time 393 Server 0 service finished
# take new customer from the queue
# Time 394  Arrival Event of agent 85
# customerQueue = 1
# Time 397 Server 1 service finished
# take new customer from the queue
# Time 399 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 399 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 402  Arrival Event of agent 86
# server 2 is Busy
# Time 408  Arrival Event of agent 87
# server 3 is Busy
# Time 409 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 412  Arrival Event of agent 88
# server 0 is Busy
# Time 413 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 415  Arrival Event of agent 89
# server 1 is Busy
# Time 417  Arrival Event of agent 90
# customerQueue = 1
# Time 419 Server 2 service finished
# take new customer from the queue
# Time 425 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 425  Arrival Event of agent 91
# server 3 is Busy
# Time 427  Arrival Event of agent 92
# customerQueue = 1
# Time 430 Server 0 service finished
# take new customer from the queue
# Time 430  Arrival Event of agent 93
# customerQueue = 1
# Time 431 Server 1 service finished
# take new customer from the queue
# Time 434 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 435  Arrival Event of agent 94
# server 2 is Busy
# Time 437  Arrival Event of agent 95
# customerQueue = 1
# Time 442 Server 3 service finished
# take new customer from the queue
# Time 444  Arrival Event of agent 96
# customerQueue = 1
# Time 447 Server 0 service finished
# take new customer from the queue
# Time 447 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 450  Arrival Event of agent 97
# server 1 is Busy
# Time 452 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 454  Arrival Event of agent 98
# server 2 is Busy
# Time 458 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 461  Arrival Event of agent 99
# server 3 is Busy
# Time 463 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 466 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 468 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 476 Server 3 service finished
# server 3 is Idle (do nothing)
#
# Average waiting time: 0.87
#
# Probability that a customer has to wait: 0.24
#
# Probability of an Idle server: -2.38
#
# Average service time: 16.08
#
# Average time between arrivals: 4.66
#
# Average waiting time for those who wait: 3.62
#
# Average time a customer spends in the system: 16.95
#
# Average time a customer spends in the system (alternative): 16.95

# %%
# QUEUE TYPE: Shortest queue
queue_type = "Shortest queue"

custm = stats.rv_discrete(name="custm", values=(service_xk, service_pk), seed = seed)
# ---- Customer Statistics ----
class customerStat:
    def __init__(self):
        self.id = -1
        self.arrivalTime = -1
        self.serviceTime = -1
        self.interArrivalTime = 0
        self.serviceBegins = -1
        self.waitingTimeInQueue = 0
        self.serviceEnds = -1
        self.timeInSystem = -1
        self.idleTimeOfServer = 0


# ---- Arrival Event ----
class ArrivalEvent:
    def __init__(self):
        self.eTime = 0.0

    def Execute(self):
        customer = customerStat()
        customer.id = DEVS.newId
        customer.arrivalTime = self.eTime
        if len(DEVS.stats) > 0:
            customer.interArrivalTime = (
                customer.arrivalTime - DEVS.stats[-1].arrivalTime
            )

        print("Time %d" % self.eTime, " Arrival Event of agent {0}".format(customer.id))
        if DEVS.newId < maxAngents - 1:
            NextArrival = ArrivalEvent()
            NextArrival.eTime = self.eTime + random.randint(
                arrivalRateMin, arrivalRateMax
            )
            DEVS.EQ.AddEvent(NextArrival)

        server = -1
        # Server choosing policy
        server = DEVS.serverQueue.index(min(DEVS.serverQueue, key=len))

        print("server %d add element to local queue" % server)

        Service = ServiceEvent(server)
        serviceTime = custm.rvs()
        customer.serviceTime = serviceTime
        # Time when last event ended
        customer.serviceBegins = (
            DEVS.serverQueue[server][-1] if DEVS.serverQueue[server] else self.eTime
        )
        Service.eTime = self.eTime + serviceTime

        # Append event ending time to queue
        DEVS.serverQueue[server].append(Service.eTime)

        Service.id = customer.id
        DEVS.EQ.AddEvent(Service)

        # server is Busy is not an option - all customers divided into server queues
        # else:
        #     # increase waiting line
        #     DEVS.customerQueue.append(customer.id)
        #     print("customerQueue = %d" % len(DEVS.customerQueue))

        DEVS.newId = DEVS.newId + 1
        DEVS.stats.append(customer)


# ---- Service (END) Event ----
class ServiceEvent:
    def __init__(self, n):
        self.eTime = 0.0
        self.number = n
        self.id = 0

    def Execute(self):
        ind = [i for i, val in enumerate(DEVS.stats) if val.id == self.id][0]
        DEVS.stats[ind].serviceEnds = self.eTime
        DEVS.stats[ind].timeInSystem = (
            DEVS.stats[ind].serviceEnds - DEVS.stats[ind].arrivalTime
        )
        DEVS.stats[ind].waitingTimeInQueue = (
            DEVS.stats[ind].serviceBegins - DEVS.stats[ind].arrivalTime
        )  # 0 without queue
        DEVS.stats[ind].idleTimeOfServer = (
            DEVS.stats[ind].serviceBegins - DEVS.lastServedTime
        )

        print(
            "Time %d" % self.eTime,
            "Server %d service finished" % self.number,
        )
        if len(DEVS.customerQueue) > 0:
            qid = DEVS.customerQueue.pop(0)
            qind = [i for i, val in enumerate(DEVS.stats) if val.id == qid][0]
            Service = ServiceEvent(self.number)
            serviceTime = custm.rvs()
            Service.eTime = self.eTime + serviceTime
            Service.id = qid
            DEVS.stats[qind].serviceBegins = self.eTime
            DEVS.stats[qind].serviceTime = serviceTime
            DEVS.EQ.AddEvent(Service)
            print("take new customer from the queue")
        else:
            DEVS.serverIdle[self.number] = True
            DEVS.serverQueue[self.number].pop(0)
            print(
                "server %d queue is %d"
                % (self.number, len(DEVS.serverQueue[self.number]))
            )

        DEVS.lastServedTime = self.eTime


# run simulation
AE = ArrivalEvent()
DEVS.EQ.AddEvent(AE)

number_of_servers = 4
# simulation attributes
DEVS.customerQueue = []
DEVS.stats = []
DEVS.newId = 0
DEVS.serverIdle = [True for i in range(number_of_servers)]
DEVS.lastServedTime = 0  # for Idle time
DEVS.serverQueue = [[] for i in range(number_of_servers)]

# --- SIMULATION ---
while DEVS.EQ.QueueSize() > 0:
    DEVS.ProcessNextEvent()

# --- STATISTICS ---

#  --- store all in file  ---
f = open("output.csv", "w")
f.write(
    "Id;Interarrival Time;Arrival Time;Service Time;Time Service Begins;Waiting time in Queue;Time Service Ends;Time Customer Spends in System;Idle time of Server\n"
)
for s in DEVS.stats:
    f.write(
        "{0};{1};{2};{3};{4};{5};{6};{7};{8}\n".format(
            s.id,
            s.interArrivalTime,
            s.arrivalTime,
            s.serviceTime,
            s.serviceBegins,
            s.waitingTimeInQueue,
            s.serviceEnds,
            s.timeInSystem,
            s.idleTimeOfServer,
        )
    )
f.close()

# 1) Average waiting time in queue
avTimeInQueue = sum([x.waitingTimeInQueue for x in DEVS.stats]) / len(DEVS.stats)
print("\nAverage waiting time: {0:.2f}".format(avTimeInQueue))

# 2) Probability that a customer has to wait
probToWait = len([x for x in DEVS.stats if x.waitingTimeInQueue > 0]) / len(DEVS.stats)
print("\nProbability that a customer has to wait: {0:.2f}".format(probToWait))

# 3) Probability of an Idle server
probIdle = sum([x.idleTimeOfServer for x in DEVS.stats]) / DEVS.GlobalTime
print("\nProbability of an Idle server: {0:.2f}".format(probIdle))

# 4) Average service time (theoretical 3.2)
avServiceTime = sum([x.serviceTime for x in DEVS.stats]) / len(DEVS.stats)
print("\nAverage service time: {0:.2f}".format(avServiceTime))

# 5) Average time between arrivals (theoretical 4.5)
avTimeBetwArr = sum([x.interArrivalTime for x in DEVS.stats]) / (len(DEVS.stats) - 1)
print("\nAverage time between arrivals: {0:.2f}".format(avTimeBetwArr))

# 6) Average waiting time for those who wait
numOfCustWhoWait = len([x for x in DEVS.stats if x.waitingTimeInQueue > 0])
avTimeWhoWait = sum([x.waitingTimeInQueue for x in DEVS.stats]) / numOfCustWhoWait
print("\nAverage waiting time for those who wait: {0:.2f}".format(avTimeWhoWait))

# 7) Average time a customer spends in the system
avTimeInTheSystem1 = sum([x.timeInSystem for x in DEVS.stats]) / len(DEVS.stats)
print(
    "\nAverage time a customer spends in the system: {0:.2f}".format(avTimeInTheSystem1)
)

avTimeInTheSystem2 = avTimeInQueue + avServiceTime
print(
    "\nAverage time a customer spends in the system (alternative): {0:.2f}".format(
        avTimeInTheSystem2
    )
)

total_time[queue_type] = DEVS.lastServedTime
avg_queue_time[queue_type] = avTimeInQueue
waited_custs[queue_type] = numOfCustWhoWait
# Out:
# Time 0  Arrival Event of agent 0
# server 0 add element to local queue
# Time 2  Arrival Event of agent 1
# server 1 add element to local queue
# Time 8  Arrival Event of agent 2
# server 2 add element to local queue
# Time 9  Arrival Event of agent 3
# server 3 add element to local queue
# Time 11  Arrival Event of agent 4
# server 0 add element to local queue
# Time 16 Server 0 service finished
# server 0 queue is 1
# Time 17  Arrival Event of agent 5
# server 0 add element to local queue
# Time 21 Server 1 service finished
# server 1 queue is 0
# Time 23  Arrival Event of agent 6
# server 1 add element to local queue
# Time 24  Arrival Event of agent 7
# server 1 add element to local queue
# Time 25 Server 2 service finished
# server 2 queue is 0
# Time 25 Server 3 service finished
# server 3 queue is 0
# Time 26 Server 0 service finished
# server 0 queue is 1
# Time 29  Arrival Event of agent 8
# server 2 add element to local queue
# Time 31  Arrival Event of agent 9
# server 3 add element to local queue
# Time 32 Server 0 service finished
# server 0 queue is 0
# Time 37 Server 1 service finished
# server 1 queue is 1
# Time 39  Arrival Event of agent 10
# server 0 add element to local queue
# Time 42 Server 1 service finished
# server 1 queue is 0
# Time 45  Arrival Event of agent 11
# server 1 add element to local queue
# Time 46 Server 2 service finished
# server 2 queue is 0
# Time 48 Server 3 service finished
# server 3 queue is 0
# Time 49  Arrival Event of agent 12
# server 2 add element to local queue
# Time 53 Server 0 service finished
# server 0 queue is 0
# Time 54  Arrival Event of agent 13
# server 0 add element to local queue
# Time 62  Arrival Event of agent 14
# server 3 add element to local queue
# Time 64 Server 1 service finished
# server 1 queue is 0
# Time 66 Server 2 service finished
# server 2 queue is 0
# Time 68  Arrival Event of agent 15
# server 1 add element to local queue
# Time 69 Server 0 service finished
# server 0 queue is 0
# Time 76  Arrival Event of agent 16
# server 0 add element to local queue
# Time 77 Server 3 service finished
# server 3 queue is 0
# Time 81  Arrival Event of agent 17
# server 2 add element to local queue
# Time 83 Server 1 service finished
# server 1 queue is 0
# Time 87  Arrival Event of agent 18
# server 1 add element to local queue
# Time 92 Server 0 service finished
# server 0 queue is 0
# Time 95  Arrival Event of agent 19
# server 0 add element to local queue
# Time 97 Server 2 service finished
# server 2 queue is 0
# Time 97  Arrival Event of agent 20
# server 2 add element to local queue
# Time 102  Arrival Event of agent 21
# server 3 add element to local queue
# Time 103 Server 1 service finished
# server 1 queue is 0
# Time 105  Arrival Event of agent 22
# server 1 add element to local queue
# Time 106  Arrival Event of agent 23
# server 0 add element to local queue
# Time 110 Server 0 service finished
# server 0 queue is 1
# Time 111  Arrival Event of agent 24
# server 0 add element to local queue
# Time 114 Server 2 service finished
# server 2 queue is 0
# Time 117 Server 3 service finished
# server 3 queue is 0
# Time 119  Arrival Event of agent 25
# server 2 add element to local queue
# Time 120 Server 1 service finished
# server 1 queue is 0
# Time 122 Server 0 service finished
# server 0 queue is 1
# Time 127 Server 0 service finished
# server 0 queue is 0
# Time 127  Arrival Event of agent 26
# server 0 add element to local queue
# Time 132  Arrival Event of agent 27
# server 1 add element to local queue
# Time 136 Server 2 service finished
# server 2 queue is 0
# Time 139  Arrival Event of agent 28
# server 2 add element to local queue
# Time 142 Server 0 service finished
# server 0 queue is 0
# Time 142  Arrival Event of agent 29
# server 0 add element to local queue
# Time 148 Server 1 service finished
# server 1 queue is 0
# Time 148  Arrival Event of agent 30
# server 1 add element to local queue
# Time 154  Arrival Event of agent 31
# server 3 add element to local queue
# Time 155 Server 2 service finished
# server 2 queue is 0
# Time 156 Server 0 service finished
# server 0 queue is 0
# Time 156  Arrival Event of agent 32
# server 0 add element to local queue
# Time 162  Arrival Event of agent 33
# server 2 add element to local queue
# Time 165 Server 1 service finished
# server 1 queue is 0
# Time 169 Server 3 service finished
# server 3 queue is 0
# Time 170 Server 0 service finished
# server 0 queue is 0
# Time 170  Arrival Event of agent 34
# server 0 add element to local queue
# Time 177  Arrival Event of agent 35
# server 1 add element to local queue
# Time 180 Server 2 service finished
# server 2 queue is 0
# Time 180  Arrival Event of agent 36
# server 2 add element to local queue
# Time 187  Arrival Event of agent 37
# server 3 add element to local queue
# Time 189 Server 0 service finished
# server 0 queue is 0
# Time 190  Arrival Event of agent 38
# server 0 add element to local queue
# Time 191  Arrival Event of agent 39
# server 0 add element to local queue
# Time 194 Server 1 service finished
# server 1 queue is 0
# Time 196 Server 2 service finished
# server 2 queue is 0
# Time 198  Arrival Event of agent 40
# server 1 add element to local queue
# Time 201 Server 3 service finished
# server 3 queue is 0
# Time 203  Arrival Event of agent 41
# server 2 add element to local queue
# Time 207 Server 0 service finished
# server 0 queue is 1
# Time 207 Server 0 service finished
# server 0 queue is 0
# Time 208  Arrival Event of agent 42
# server 0 add element to local queue
# Time 210  Arrival Event of agent 43
# server 3 add element to local queue
# Time 212  Arrival Event of agent 44
# server 0 add element to local queue
# Time 213 Server 1 service finished
# server 1 queue is 0
# Time 219 Server 2 service finished
# server 2 queue is 0
# Time 219  Arrival Event of agent 45
# server 1 add element to local queue
# Time 222 Server 0 service finished
# server 0 queue is 1
# Time 225  Arrival Event of agent 46
# server 2 add element to local queue
# Time 227 Server 0 service finished
# server 0 queue is 0
# Time 228 Server 3 service finished
# server 3 queue is 0
# Time 228  Arrival Event of agent 47
# server 0 add element to local queue
# Time 235  Arrival Event of agent 48
# server 3 add element to local queue
# Time 236 Server 1 service finished
# server 1 queue is 0
# Time 236  Arrival Event of agent 49
# server 1 add element to local queue
# Time 241 Server 2 service finished
# server 2 queue is 0
# Time 242  Arrival Event of agent 50
# server 2 add element to local queue
# Time 244 Server 0 service finished
# server 0 queue is 0
# Time 244  Arrival Event of agent 51
# server 0 add element to local queue
# Time 250  Arrival Event of agent 52
# server 0 add element to local queue
# Time 251 Server 3 service finished
# server 3 queue is 0
# Time 251 Server 1 service finished
# server 1 queue is 0
# Time 252  Arrival Event of agent 53
# server 1 add element to local queue
# Time 260  Arrival Event of agent 54
# server 3 add element to local queue
# Time 261 Server 2 service finished
# server 2 queue is 0
# Time 261 Server 0 service finished
# server 0 queue is 1
# Time 266  Arrival Event of agent 55
# server 2 add element to local queue
# Time 267  Arrival Event of agent 56
# server 0 add element to local queue
# Time 268 Server 0 service finished
# server 0 queue is 1
# Time 269  Arrival Event of agent 57
# server 0 add element to local queue
# Time 270 Server 1 service finished
# server 1 queue is 0
# Time 275  Arrival Event of agent 58
# server 1 add element to local queue
# Time 276 Server 3 service finished
# server 3 queue is 0
# Time 277  Arrival Event of agent 59
# server 3 add element to local queue
# Time 281 Server 0 service finished
# server 0 queue is 1
# Time 283  Arrival Event of agent 60
# server 0 add element to local queue
# Time 284 Server 2 service finished
# server 2 queue is 0
# Time 284 Server 0 service finished
# server 0 queue is 1
# Time 288  Arrival Event of agent 61
# server 2 add element to local queue
# Time 289 Server 1 service finished
# server 1 queue is 0
# Time 290  Arrival Event of agent 62
# server 1 add element to local queue
# Time 293 Server 3 service finished
# server 3 queue is 0
# Time 296  Arrival Event of agent 63
# server 3 add element to local queue
# Time 299 Server 0 service finished
# server 0 queue is 0
# Time 301  Arrival Event of agent 64
# server 0 add element to local queue
# Time 303 Server 2 service finished
# server 2 queue is 0
# Time 304  Arrival Event of agent 65
# server 2 add element to local queue
# Time 305  Arrival Event of agent 66
# server 0 add element to local queue
# Time 307 Server 1 service finished
# server 1 queue is 0
# Time 311  Arrival Event of agent 67
# server 1 add element to local queue
# Time 312 Server 3 service finished
# server 3 queue is 0
# Time 316 Server 0 service finished
# server 0 queue is 1
# Time 318  Arrival Event of agent 68
# server 3 add element to local queue
# Time 320 Server 2 service finished
# server 2 queue is 0
# Time 320 Server 0 service finished
# server 0 queue is 0
# Time 325  Arrival Event of agent 69
# server 0 add element to local queue
# Time 328 Server 1 service finished
# server 1 queue is 0
# Time 331  Arrival Event of agent 70
# server 1 add element to local queue
# Time 332 Server 3 service finished
# server 3 queue is 0
# Time 332  Arrival Event of agent 71
# server 2 add element to local queue
# Time 334  Arrival Event of agent 72
# server 3 add element to local queue
# Time 337  Arrival Event of agent 73
# server 0 add element to local queue
# Time 343  Arrival Event of agent 74
# server 1 add element to local queue
# Time 344 Server 0 service finished
# server 0 queue is 1
# Time 344  Arrival Event of agent 75
# server 0 add element to local queue
# Time 347 Server 2 service finished
# server 2 queue is 0
# Time 348 Server 1 service finished
# server 1 queue is 1
# Time 348 Server 3 service finished
# server 3 queue is 0
# Time 348  Arrival Event of agent 76
# server 2 add element to local queue
# Time 354 Server 0 service finished
# server 0 queue is 1
# Time 354  Arrival Event of agent 77
# server 3 add element to local queue
# Time 355  Arrival Event of agent 78
# server 0 add element to local queue
# Time 359  Arrival Event of agent 79
# server 1 add element to local queue
# Time 360 Server 1 service finished
# server 1 queue is 1
# Time 361 Server 0 service finished
# server 0 queue is 1
# Time 364  Arrival Event of agent 80
# server 0 add element to local queue
# Time 365 Server 2 service finished
# server 2 queue is 0
# Time 368 Server 3 service finished
# server 3 queue is 0
# Time 371 Server 0 service finished
# server 0 queue is 1
# Time 371  Arrival Event of agent 81
# server 2 add element to local queue
# Time 374 Server 1 service finished
# server 1 queue is 0
# Time 378  Arrival Event of agent 82
# server 1 add element to local queue
# Time 381  Arrival Event of agent 83
# server 3 add element to local queue
# Time 382 Server 0 service finished
# server 0 queue is 0
# Time 385  Arrival Event of agent 84
# server 0 add element to local queue
# Time 388 Server 2 service finished
# server 2 queue is 0
# Time 390  Arrival Event of agent 85
# server 2 add element to local queue
# Time 394 Server 1 service finished
# server 1 queue is 0
# Time 395 Server 3 service finished
# server 3 queue is 0
# Time 398  Arrival Event of agent 86
# server 1 add element to local queue
# Time 399  Arrival Event of agent 87
# server 3 add element to local queue
# Time 401 Server 0 service finished
# server 0 queue is 0
# Time 402  Arrival Event of agent 88
# server 0 add element to local queue
# Time 406 Server 2 service finished
# server 2 queue is 0
# Time 410  Arrival Event of agent 89
# server 2 add element to local queue
# Time 414  Arrival Event of agent 90
# server 0 add element to local queue
# Time 415 Server 1 service finished
# server 1 queue is 0
# Time 416 Server 3 service finished
# server 3 queue is 0
# Time 418  Arrival Event of agent 91
# server 1 add element to local queue
# Time 420 Server 0 service finished
# server 0 queue is 1
# Time 425  Arrival Event of agent 92
# server 3 add element to local queue
# Time 426 Server 2 service finished
# server 2 queue is 0
# Time 429 Server 0 service finished
# server 0 queue is 0
# Time 430  Arrival Event of agent 93
# server 0 add element to local queue
# Time 433  Arrival Event of agent 94
# server 2 add element to local queue
# Time 435 Server 1 service finished
# server 1 queue is 0
# Time 437  Arrival Event of agent 95
# server 1 add element to local queue
# Time 441  Arrival Event of agent 96
# server 0 add element to local queue
# Time 442 Server 3 service finished
# server 3 queue is 0
# Time 442  Arrival Event of agent 97
# server 3 add element to local queue
# Time 446 Server 0 service finished
# server 0 queue is 1
# Time 446  Arrival Event of agent 98
# server 0 add element to local queue
# Time 450 Server 2 service finished
# server 2 queue is 0
# Time 453 Server 1 service finished
# server 1 queue is 0
# Time 454  Arrival Event of agent 99
# server 1 add element to local queue
# Time 457 Server 0 service finished
# server 0 queue is 1
# Time 458 Server 3 service finished
# server 3 queue is 0
# Time 460 Server 0 service finished
# server 0 queue is 0
# Time 469 Server 1 service finished
# server 1 queue is 0
#
# Average waiting time: 1.62
#
# Probability that a customer has to wait: 0.21
#
# Probability of an Idle server: -2.08
#
# Average service time: 16.08
#
# Average time between arrivals: 4.59
#
# Average waiting time for those who wait: 7.71
#
# Average time a customer spends in the system: 16.08
#
# Average time a customer spends in the system (alternative): 17.70

# %%
# QUEUE TYPE: Dynamic general queue
queue_type = "Dynamic g queue"

server_dynamic[queue_type] = []

custm = stats.rv_discrete(name="custm", values=(service_xk, service_pk), seed = seed)
# ---- Customer Statistics ----
class customerStat:
    def __init__(self):
        self.id = -1
        self.arrivalTime = -1
        self.serviceTime = -1
        self.interArrivalTime = 0
        self.serviceBegins = -1
        self.waitingTimeInQueue = 0
        self.serviceEnds = -1
        self.timeInSystem = -1
        self.idleTimeOfServer = 0


# ---- Arrival Event ----
class ArrivalEvent:
    def __init__(self):
        self.eTime = 0.0

    def Execute(self):
        customer = customerStat()
        customer.id = DEVS.newId
        customer.arrivalTime = self.eTime
        if len(DEVS.stats) > 0:
            customer.interArrivalTime = (
                customer.arrivalTime - DEVS.stats[-1].arrivalTime
            )

        print("Time %d" % self.eTime, " Arrival Event of agent {0}".format(customer.id))
        if DEVS.newId < maxAngents - 1:
            NextArrival = ArrivalEvent()
            NextArrival.eTime = self.eTime + random.randint(
                arrivalRateMin, arrivalRateMax
            )
            DEVS.EQ.AddEvent(NextArrival)

        server = -1
        # Server choosing policy
        free_servers = len([item for item in DEVS.serverIdle if item == True])

        if (free_servers == 0) and (DEVS.extended == False):
            server = 4
            DEVS.extended = True
        elif (free_servers >= 2) and (DEVS.extended == True):
            DEVS.extended = False
            for i in range(len(DEVS.serverIdle) - 1):
                if DEVS.serverIdle[i] == True:
                    server = i
                    break
        else:
            for i in range(len(DEVS.serverIdle)):
                if DEVS.serverIdle[i] == True:
                    server = i
                    break

        # server is Free
        if server != -1:
            DEVS.serverIdle[server] = False
            print("server %d is Busy" % server)
            Service = ServiceEvent(server)
            serviceTime = custm.rvs()
            customer.serviceTime = serviceTime
            customer.serviceBegins = self.eTime  # current time
            Service.eTime = self.eTime + serviceTime
            Service.id = customer.id
            DEVS.EQ.AddEvent(Service)
        # server is Busy
        else:
            # increase waiting line
            DEVS.customerQueue.append(customer.id)
            print("customerQueue = %d" % len(DEVS.customerQueue))

        DEVS.newId = DEVS.newId + 1
        DEVS.stats.append(customer)


# ---- Service (END) Event ----
class ServiceEvent:
    def __init__(self, n):
        self.eTime = 0.0
        self.number = n
        self.id = 0

    def Execute(self):
        ind = [i for i, val in enumerate(DEVS.stats) if val.id == self.id][0]
        DEVS.stats[ind].serviceEnds = self.eTime
        DEVS.stats[ind].timeInSystem = (
            DEVS.stats[ind].serviceEnds - DEVS.stats[ind].arrivalTime
        )
        DEVS.stats[ind].waitingTimeInQueue = (
            DEVS.stats[ind].serviceBegins - DEVS.stats[ind].arrivalTime
        )  # 0 without queue
        DEVS.stats[ind].idleTimeOfServer = (
            DEVS.stats[ind].serviceBegins - DEVS.lastServedTime
        )

        print(
            "Time %d" % self.eTime,
            "Server %d service finished" % self.number,
        )
        if len(DEVS.customerQueue) > 0:
            qid = DEVS.customerQueue.pop(0)
            qind = [i for i, val in enumerate(DEVS.stats) if val.id == qid][0]
            Service = ServiceEvent(self.number)
            serviceTime = custm.rvs()
            Service.eTime = self.eTime + serviceTime
            Service.id = qid
            DEVS.stats[qind].serviceBegins = self.eTime
            DEVS.stats[qind].serviceTime = serviceTime
            DEVS.EQ.AddEvent(Service)
            print("take new customer from the queue")
        else:
            DEVS.serverIdle[self.number] = True
            print("server %d is Idle (do nothing)" % self.number)

        DEVS.lastServedTime = self.eTime
        
        working_servers = len([item for item in DEVS.serverIdle[:-1] if item == False])
        if (DEVS.extended == True) and (DEVS.serverIdle[-1] == False):
            working_servers += 1

        server_dynamic[queue_type].append((DEVS.lastServedTime, working_servers))



# run simulation
AE = ArrivalEvent()
DEVS.EQ.AddEvent(AE)

number_of_servers = 4
# simulation attributes
DEVS.customerQueue = []
DEVS.stats = []
DEVS.newId = 0
DEVS.serverIdle = [True for i in range(number_of_servers + 1)]
DEVS.extended = False
DEVS.lastServedTime = 0  # for Idle time

# --- SIMULATION ---
while DEVS.EQ.QueueSize() > 0:
    DEVS.ProcessNextEvent()

# --- STATISTICS ---

#  --- store all in file  ---
f = open("output.csv", "w")
f.write(
    "Id;Interarrival Time;Arrival Time;Service Time;Time Service Begins;Waiting time in Queue;Time Service Ends;Time Customer Spends in System;Idle time of Server\n"
)
for s in DEVS.stats:
    f.write(
        "{0};{1};{2};{3};{4};{5};{6};{7};{8}\n".format(
            s.id,
            s.interArrivalTime,
            s.arrivalTime,
            s.serviceTime,
            s.serviceBegins,
            s.waitingTimeInQueue,
            s.serviceEnds,
            s.timeInSystem,
            s.idleTimeOfServer,
        )
    )
f.close()

# 1) Average waiting time in queue
avTimeInQueue = sum([x.waitingTimeInQueue for x in DEVS.stats]) / len(DEVS.stats)
print("\nAverage waiting time: {0:.2f}".format(avTimeInQueue))

# 2) Probability that a customer has to wait
probToWait = len([x for x in DEVS.stats if x.waitingTimeInQueue > 0]) / len(DEVS.stats)
print("\nProbability that a customer has to wait: {0:.2f}".format(probToWait))

# 3) Probability of an Idle server
probIdle = sum([x.idleTimeOfServer for x in DEVS.stats]) / DEVS.GlobalTime
print("\nProbability of an Idle server: {0:.2f}".format(probIdle))

# 4) Average service time (theoretical 3.2)
avServiceTime = sum([x.serviceTime for x in DEVS.stats]) / len(DEVS.stats)
print("\nAverage service time: {0:.2f}".format(avServiceTime))

# 5) Average time between arrivals (theoretical 4.5)
avTimeBetwArr = sum([x.interArrivalTime for x in DEVS.stats]) / (len(DEVS.stats) - 1)
print("\nAverage time between arrivals: {0:.2f}".format(avTimeBetwArr))

# 6) Average waiting time for those who wait
numOfCustWhoWait = len([x for x in DEVS.stats if x.waitingTimeInQueue > 0])
avTimeWhoWait = sum([x.waitingTimeInQueue for x in DEVS.stats]) / numOfCustWhoWait
print("\nAverage waiting time for those who wait: {0:.2f}".format(avTimeWhoWait))

# 7) Average time a customer spends in the system
avTimeInTheSystem1 = sum([x.timeInSystem for x in DEVS.stats]) / len(DEVS.stats)
print(
    "\nAverage time a customer spends in the system: {0:.2f}".format(avTimeInTheSystem1)
)

avTimeInTheSystem2 = avTimeInQueue + avServiceTime
print(
    "\nAverage time a customer spends in the system (alternative): {0:.2f}".format(
        avTimeInTheSystem2
    )
)

total_time[queue_type] = DEVS.lastServedTime
avg_queue_time[queue_type] = avTimeInQueue
waited_custs[queue_type] = numOfCustWhoWait
# Out:
# Time 0  Arrival Event of agent 0
# server 0 is Busy
# Time 1  Arrival Event of agent 1
# server 1 is Busy
# Time 8  Arrival Event of agent 2
# server 2 is Busy
# Time 14  Arrival Event of agent 3
# server 3 is Busy
# Time 16 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 18  Arrival Event of agent 4
# server 0 is Busy
# Time 19  Arrival Event of agent 5
# server 4 is Busy
# Time 20 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 20  Arrival Event of agent 6
# server 1 is Busy
# Time 21  Arrival Event of agent 7
# server 4 is Busy
# Time 22  Arrival Event of agent 8
# customerQueue = 1
# Time 25 Server 2 service finished
# take new customer from the queue
# Time 26  Arrival Event of agent 9
# customerQueue = 1
# Time 28  Arrival Event of agent 10
# customerQueue = 2
# Time 30 Server 3 service finished
# take new customer from the queue
# Time 30  Arrival Event of agent 11
# customerQueue = 2
# Time 33 Server 0 service finished
# take new customer from the queue
# Time 34 Server 4 service finished
# take new customer from the queue
# Time 34 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 34  Arrival Event of agent 12
# server 1 is Busy
# Time 39 Server 4 service finished
# server 4 is Idle (do nothing)
# Time 40  Arrival Event of agent 13
# server 4 is Busy
# Time 42 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 44  Arrival Event of agent 14
# server 2 is Busy
# Time 47 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 47 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 50  Arrival Event of agent 15
# server 0 is Busy
# Time 51 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 53 Server 4 service finished
# server 4 is Idle (do nothing)
# Time 55 Server 4 service finished
# server 4 is Idle (do nothing)
# Time 56  Arrival Event of agent 16
# server 1 is Busy
# Time 57  Arrival Event of agent 17
# server 3 is Busy
# Time 59 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 64  Arrival Event of agent 18
# server 2 is Busy
# Time 65 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 72 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 72  Arrival Event of agent 19
# server 0 is Busy
# Time 73 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 78  Arrival Event of agent 20
# server 1 is Busy
# Time 80 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 80  Arrival Event of agent 21
# server 2 is Busy
# Time 84  Arrival Event of agent 22
# server 3 is Busy
# Time 87 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 91  Arrival Event of agent 23
# server 0 is Busy
# Time 95 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 95 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 99 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 99  Arrival Event of agent 24
# server 1 is Busy
# Time 100  Arrival Event of agent 25
# server 2 is Busy
# Time 107 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 108  Arrival Event of agent 26
# server 0 is Busy
# Time 110  Arrival Event of agent 27
# server 3 is Busy
# Time 113  Arrival Event of agent 28
# server 4 is Busy
# Time 115 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 117 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 117  Arrival Event of agent 29
# server 1 is Busy
# Time 123 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 124  Arrival Event of agent 30
# server 0 is Busy
# Time 126 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 127  Arrival Event of agent 31
# server 2 is Busy
# Time 129 Server 4 service finished
# server 4 is Idle (do nothing)
# Time 130  Arrival Event of agent 32
# server 3 is Busy
# Time 131 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 131  Arrival Event of agent 33
# server 1 is Busy
# Time 132  Arrival Event of agent 34
# server 4 is Busy
# Time 133  Arrival Event of agent 35
# server 4 is Busy
# Time 137  Arrival Event of agent 36
# customerQueue = 1
# Time 141 Server 0 service finished
# take new customer from the queue
# Time 141  Arrival Event of agent 37
# customerQueue = 1
# Time 142 Server 2 service finished
# take new customer from the queue
# Time 144 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 149 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 149  Arrival Event of agent 38
# server 1 is Busy
# Time 150 Server 4 service finished
# server 4 is Idle (do nothing)
# Time 151 Server 4 service finished
# server 4 is Idle (do nothing)
# Time 151  Arrival Event of agent 39
# server 3 is Busy
# Time 156 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 156  Arrival Event of agent 40
# server 2 is Busy
# Time 157 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 159  Arrival Event of agent 41
# server 0 is Busy
# Time 166 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 166  Arrival Event of agent 42
# server 1 is Busy
# Time 167 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 171 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 171  Arrival Event of agent 43
# server 2 is Busy
# Time 173  Arrival Event of agent 44
# server 3 is Busy
# Time 175 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 179  Arrival Event of agent 45
# server 0 is Busy
# Time 180 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 183  Arrival Event of agent 46
# server 1 is Busy
# Time 186  Arrival Event of agent 47
# server 4 is Busy
# Time 188 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 189 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 189  Arrival Event of agent 48
# server 2 is Busy
# Time 194  Arrival Event of agent 49
# server 3 is Busy
# Time 196 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 198  Arrival Event of agent 50
# server 0 is Busy
# Time 199 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 202 Server 4 service finished
# server 4 is Idle (do nothing)
# Time 203  Arrival Event of agent 51
# server 1 is Busy
# Time 205 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 205  Arrival Event of agent 52
# server 2 is Busy
# Time 209 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 213  Arrival Event of agent 53
# server 3 is Busy
# Time 216  Arrival Event of agent 54
# server 4 is Busy
# Time 217 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 220 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 221  Arrival Event of agent 55
# server 0 is Busy
# Time 223 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 226  Arrival Event of agent 56
# server 1 is Busy
# Time 230  Arrival Event of agent 57
# server 2 is Busy
# Time 231 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 232 Server 4 service finished
# server 4 is Idle (do nothing)
# Time 238  Arrival Event of agent 58
# server 3 is Busy
# Time 239 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 240 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 241  Arrival Event of agent 59
# server 0 is Busy
# Time 245 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 249  Arrival Event of agent 60
# server 1 is Busy
# Time 251  Arrival Event of agent 61
# server 2 is Busy
# Time 252 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 252  Arrival Event of agent 62
# server 3 is Busy
# Time 257 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 259  Arrival Event of agent 63
# server 0 is Busy
# Time 264  Arrival Event of agent 64
# server 4 is Busy
# Time 265 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 266 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 266  Arrival Event of agent 65
# server 1 is Busy
# Time 269 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 271  Arrival Event of agent 66
# server 2 is Busy
# Time 275 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 275  Arrival Event of agent 67
# server 0 is Busy
# Time 279 Server 4 service finished
# server 4 is Idle (do nothing)
# Time 280  Arrival Event of agent 68
# server 3 is Busy
# Time 282 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 283  Arrival Event of agent 69
# server 1 is Busy
# Time 286 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 290  Arrival Event of agent 70
# server 2 is Busy
# Time 292 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 294 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 298  Arrival Event of agent 71
# server 0 is Busy
# Time 300  Arrival Event of agent 72
# server 3 is Busy
# Time 302 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 304  Arrival Event of agent 73
# server 1 is Busy
# Time 307 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 310  Arrival Event of agent 74
# server 2 is Busy
# Time 313 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 314 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 317  Arrival Event of agent 75
# server 0 is Busy
# Time 321 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 325  Arrival Event of agent 76
# server 1 is Busy
# Time 327 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 327  Arrival Event of agent 77
# server 2 is Busy
# Time 331  Arrival Event of agent 78
# server 3 is Busy
# Time 333  Arrival Event of agent 79
# server 4 is Busy
# Time 334 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 337  Arrival Event of agent 80
# server 0 is Busy
# Time 338  Arrival Event of agent 81
# server 4 is Busy
# Time 341 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 342 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 345  Arrival Event of agent 82
# server 1 is Busy
# Time 346  Arrival Event of agent 83
# server 2 is Busy
# Time 347 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 347  Arrival Event of agent 84
# server 3 is Busy
# Time 348 Server 4 service finished
# server 4 is Idle (do nothing)
# Time 355 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 355 Server 4 service finished
# server 4 is Idle (do nothing)
# Time 355  Arrival Event of agent 85
# server 0 is Busy
# Time 356  Arrival Event of agent 86
# server 4 is Busy
# Time 359  Arrival Event of agent 87
# server 4 is Busy
# Time 360 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 361 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 363 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 364  Arrival Event of agent 88
# server 1 is Busy
# Time 365  Arrival Event of agent 89
# server 2 is Busy
# Time 371 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 373 Server 4 service finished
# server 4 is Idle (do nothing)
# Time 373  Arrival Event of agent 90
# server 0 is Busy
# Time 376 Server 4 service finished
# server 4 is Idle (do nothing)
# Time 381 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 381  Arrival Event of agent 91
# server 2 is Busy
# Time 382 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 388 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 388  Arrival Event of agent 92
# server 0 is Busy
# Time 391  Arrival Event of agent 93
# server 1 is Busy
# Time 397  Arrival Event of agent 94
# server 3 is Busy
# Time 398 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 400  Arrival Event of agent 95
# server 2 is Busy
# Time 405 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 406  Arrival Event of agent 96
# server 0 is Busy
# Time 407 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 414 Server 3 service finished
# server 3 is Idle (do nothing)
# Time 414  Arrival Event of agent 97
# server 1 is Busy
# Time 416 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 416  Arrival Event of agent 98
# server 2 is Busy
# Time 422 Server 0 service finished
# server 0 is Idle (do nothing)
# Time 424  Arrival Event of agent 99
# server 0 is Busy
# Time 430 Server 1 service finished
# server 1 is Idle (do nothing)
# Time 430 Server 2 service finished
# server 2 is Idle (do nothing)
# Time 439 Server 0 service finished
# server 0 is Idle (do nothing)
#
# Average waiting time: 0.21
#
# Probability that a customer has to wait: 0.06
#
# Probability of an Idle server: -2.66
#
# Average service time: 16.08
#
# Average time between arrivals: 4.28
#
# Average waiting time for those who wait: 3.50
#
# Average time a customer spends in the system: 16.29
#
# Average time a customer spends in the system (alternative): 16.29

# %%
# QUEUE TYPE: Dynamic Shortest queue

queue_type = "Dynamic Shortest"

server_dynamic[queue_type] = []
custm = stats.rv_discrete(name="custm", values=(service_xk, service_pk), seed = seed)

# ---- Customer Statistics ----
class customerStat:
    def __init__(self):
        self.id = -1
        self.arrivalTime = -1
        self.serviceTime = -1
        self.interArrivalTime = 0
        self.serviceBegins = -1
        self.waitingTimeInQueue = 0
        self.serviceEnds = -1
        self.timeInSystem = -1
        self.idleTimeOfServer = 0


# ---- Arrival Event ----
class ArrivalEvent:
    def __init__(self):
        self.eTime = 0.0

    def Execute(self):
        customer = customerStat()
        customer.id = DEVS.newId
        customer.arrivalTime = self.eTime
        if len(DEVS.stats) > 0:
            customer.interArrivalTime = (
                customer.arrivalTime - DEVS.stats[-1].arrivalTime
            )

        print("Time %d" % self.eTime, " Arrival Event of agent {0}".format(customer.id))
        if DEVS.newId < maxAngents - 1:
            NextArrival = ArrivalEvent()
            NextArrival.eTime = self.eTime + random.randint(
                arrivalRateMin, arrivalRateMax
            )
            DEVS.EQ.AddEvent(NextArrival)

        server = -1

        # Server choosing policy
        free_servers = 0
        for idx, flag in enumerate(DEVS.availableServers):
            if (flag == True) and (not DEVS.serverQueue[idx]):
                free_servers += 1

        if (free_servers == 0) and (DEVS.extended == False):
            DEVS.extended = True
            for idx, flag in reversed(list(enumerate(DEVS.availableServers))):
                if flag is False:
                    DEVS.availableServers[idx] = True
                    break
            print("Server added")

        elif (free_servers >= 2) and (DEVS.extended == True):
            DEVS.extended = False
            for idx, flag in reversed(list(enumerate(DEVS.availableServers))):
                if flag is True and (not DEVS.serverQueue[idx]):
                    DEVS.availableServers[idx] = False
                    break
            print("Server removed")

        server = DEVS.serverQueue.index(
            min(
                [
                    [None] * 100 if DEVS.availableServers[idx] == False else item
                    for idx, item in enumerate(DEVS.serverQueue)
                ],
                key=len,
            )
        )

        print("server %d add element to local queue" % server)
        Service = ServiceEvent(server)
        serviceTime = custm.rvs()
        customer.serviceTime = serviceTime
        # Time when last event ended
        customer.serviceBegins = (
            DEVS.serverQueue[server][-1] if DEVS.serverQueue[server] else self.eTime
        )
        Service.eTime = self.eTime + serviceTime

        # Append event to ending time to queue
        DEVS.serverQueue[server].append(Service.eTime)

        Service.id = customer.id
        DEVS.EQ.AddEvent(Service)

        DEVS.newId = DEVS.newId + 1
        DEVS.stats.append(customer)


# ---- Service (END) Event ----
class ServiceEvent:
    def __init__(self, n):
        self.eTime = 0.0
        self.number = n
        self.id = 0

    def Execute(self):
        ind = [i for i, val in enumerate(DEVS.stats) if val.id == self.id][0]
        DEVS.stats[ind].serviceEnds = self.eTime
        DEVS.stats[ind].timeInSystem = (
            DEVS.stats[ind].serviceEnds - DEVS.stats[ind].arrivalTime
        )
        DEVS.stats[ind].waitingTimeInQueue = (
            DEVS.stats[ind].serviceBegins - DEVS.stats[ind].arrivalTime
        )  # 0 without queue
        DEVS.stats[ind].idleTimeOfServer = (
            DEVS.stats[ind].serviceBegins - DEVS.lastServedTime
        )

        print(
            "Time %d" % self.eTime,
            "Server %d service finished" % self.number,
        )
        if len(DEVS.customerQueue) > 0:
            qid = DEVS.customerQueue.pop(0)
            qind = [i for i, val in enumerate(DEVS.stats) if val.id == qid][0]
            Service = ServiceEvent(self.number)
            serviceTime = custm.rvs()
            Service.eTime = self.eTime + serviceTime
            Service.id = qid
            DEVS.stats[qind].serviceBegins = self.eTime
            DEVS.stats[qind].serviceTime = serviceTime
            DEVS.EQ.AddEvent(Service)
            print("take new customer from the queue")
        else:
            DEVS.serverQueue[self.number].pop(0)
            print(
                "server %d queue is %d"
                % (self.number, len(DEVS.serverQueue[self.number]))
            )

        DEVS.lastServedTime = self.eTime

        working_servers = 0
        for idx, flag in reversed(list(enumerate(DEVS.availableServers))):
            if (flag == True) and (DEVS.serverQueue[idx]):
                working_servers += 1
        
        server_dynamic[queue_type].append((DEVS.lastServedTime, working_servers))


# run simulation
AE = ArrivalEvent()
DEVS.EQ.AddEvent(AE)

number_of_servers = 4
# simulation attributes
DEVS.customerQueue = []
DEVS.stats = []
DEVS.newId = 0
DEVS.availableServers = [True for i in range(number_of_servers)] + [False]
DEVS.lastServedTime = 0  # for Idle time
DEVS.extended = False
DEVS.serverQueue = [[] for i in range(number_of_servers + 1)]


# --- SIMULATION ---
while DEVS.EQ.QueueSize() > 0:
    DEVS.ProcessNextEvent()

# --- STATISTICS ---

#  --- store all in file  ---
f = open("output.csv", "w")
f.write(
    "Id;Interarrival Time;Arrival Time;Service Time;Time Service Begins;Waiting time in Queue;Time Service Ends;Time Customer Spends in System;Idle time of Server\n"
)
for s in DEVS.stats:
    f.write(
        "{0};{1};{2};{3};{4};{5};{6};{7};{8}\n".format(
            s.id,
            s.interArrivalTime,
            s.arrivalTime,
            s.serviceTime,
            s.serviceBegins,
            s.waitingTimeInQueue,
            s.serviceEnds,
            s.timeInSystem,
            s.idleTimeOfServer,
        )
    )
f.close()

last_time = DEVS.lastServedTime
print("All time: {}".format(last_time))


# 1) Average waiting time in queue
avTimeInQueue = sum([x.waitingTimeInQueue for x in DEVS.stats]) / len(DEVS.stats)
print("\nAverage waiting time: {0:.2f}".format(avTimeInQueue))

# 2) Probability that a customer has to wait
probToWait = len([x for x in DEVS.stats if x.waitingTimeInQueue > 0]) / len(DEVS.stats)
print("\nProbability that a customer has to wait: {0:.2f}".format(probToWait))

# 3) Probability of an Idle server
probIdle = sum([x.idleTimeOfServer for x in DEVS.stats]) / DEVS.GlobalTime
print("\nProbability of an Idle server: {0:.2f}".format(probIdle))

# 4) Average service time (theoretical 3.2)
avServiceTime = sum([x.serviceTime for x in DEVS.stats]) / len(DEVS.stats)
print("\nAverage service time: {0:.2f}".format(avServiceTime))

# 5) Average time between arrivals (theoretical 4.5)
avTimeBetwArr = sum([x.interArrivalTime for x in DEVS.stats]) / (len(DEVS.stats) - 1)
print("\nAverage time between arrivals: {0:.2f}".format(avTimeBetwArr))

# 6) Average waiting time for those who wait
numOfCustWhoWait = len([x for x in DEVS.stats if x.waitingTimeInQueue > 0])
avTimeWhoWait = sum([x.waitingTimeInQueue for x in DEVS.stats]) / numOfCustWhoWait
print("\nAverage waiting time for those who wait: {0:.2f}".format(avTimeWhoWait))

# 7) Average time a customer spends in the system
avTimeInTheSystem1 = sum([x.timeInSystem for x in DEVS.stats]) / len(DEVS.stats)
print(
    "\nAverage time a customer spends in the system: {0:.2f}".format(avTimeInTheSystem1)
)

avTimeInTheSystem2 = avTimeInQueue + avServiceTime
print(
    "\nAverage time a customer spends in the system (alternative): {0:.2f}".format(
        avTimeInTheSystem2
    )
)

total_time[queue_type] = DEVS.lastServedTime
avg_queue_time[queue_type] = avTimeInQueue
waited_custs[queue_type] = numOfCustWhoWait
# Out:
# Time 0  Arrival Event of agent 0
# server 0 add element to local queue
# Time 3  Arrival Event of agent 1
# server 1 add element to local queue
# Time 6  Arrival Event of agent 2
# server 2 add element to local queue
# Time 11  Arrival Event of agent 3
# server 3 add element to local queue
# Time 16 Server 0 service finished
# server 0 queue is 0
# Time 18  Arrival Event of agent 4
# server 0 add element to local queue
# Time 22 Server 1 service finished
# server 1 queue is 0
# Time 23 Server 2 service finished
# server 2 queue is 0
# Time 26  Arrival Event of agent 5
# server 1 add element to local queue
# Time 27 Server 3 service finished
# server 3 queue is 0
# Time 33 Server 0 service finished
# server 0 queue is 0
# Time 33  Arrival Event of agent 6
# server 0 add element to local queue
# Time 36  Arrival Event of agent 7
# server 2 add element to local queue
# Time 41 Server 1 service finished
# server 1 queue is 0
# Time 41  Arrival Event of agent 8
# server 1 add element to local queue
# Time 47 Server 0 service finished
# server 0 queue is 0
# Time 49  Arrival Event of agent 9
# server 0 add element to local queue
# Time 52  Arrival Event of agent 10
# server 3 add element to local queue
# Time 54 Server 2 service finished
# server 2 queue is 0
# Time 55  Arrival Event of agent 11
# server 2 add element to local queue
# Time 58 Server 1 service finished
# server 1 queue is 0
# Time 62  Arrival Event of agent 12
# server 1 add element to local queue
# Time 63  Arrival Event of agent 13
# Server added
# server 4 add element to local queue
# Time 65  Arrival Event of agent 14
# server 0 add element to local queue
# Time 66 Server 0 service finished
# server 0 queue is 1
# Time 66 Server 3 service finished
# server 3 queue is 0
# Time 70  Arrival Event of agent 15
# server 3 add element to local queue
# Time 74 Server 2 service finished
# server 2 queue is 0
# Time 78 Server 4 service finished
# server 4 queue is 0
# Time 78  Arrival Event of agent 16
# Server removed
# server 2 add element to local queue
# Time 79 Server 1 service finished
# server 1 queue is 0
# Time 80 Server 0 service finished
# server 0 queue is 0
# Time 80  Arrival Event of agent 17
# server 0 add element to local queue
# Time 85 Server 3 service finished
# server 3 queue is 0
# Time 88  Arrival Event of agent 18
# server 1 add element to local queue
# Time 93  Arrival Event of agent 19
# server 3 add element to local queue
# Time 94 Server 2 service finished
# server 2 queue is 0
# Time 94  Arrival Event of agent 20
# server 2 add element to local queue
# Time 96 Server 0 service finished
# server 0 queue is 0
# Time 102  Arrival Event of agent 21
# server 0 add element to local queue
# Time 104 Server 1 service finished
# server 1 queue is 0
# Time 107  Arrival Event of agent 22
# server 1 add element to local queue
# Time 108 Server 3 service finished
# server 3 queue is 0
# Time 109  Arrival Event of agent 23
# server 3 add element to local queue
# Time 111 Server 2 service finished
# server 2 queue is 0
# Time 114  Arrival Event of agent 24
# server 2 add element to local queue
# Time 116  Arrival Event of agent 25
# Server added
# server 4 add element to local queue
# Time 117 Server 0 service finished
# server 0 queue is 0
# Time 117  Arrival Event of agent 26
# server 0 add element to local queue
# Time 121  Arrival Event of agent 27
# server 0 add element to local queue
# Time 122 Server 1 service finished
# server 1 queue is 0
# Time 125 Server 3 service finished
# server 3 queue is 0
# Time 125  Arrival Event of agent 28
# Server removed
# server 1 add element to local queue
# Time 130 Server 2 service finished
# server 2 queue is 0
# Time 131  Arrival Event of agent 29
# server 2 add element to local queue
# Time 132 Server 0 service finished
# server 0 queue is 1
# Time 133 Server 4 service finished
# server 4 queue is 0
# Time 136  Arrival Event of agent 30
# server 3 add element to local queue
# Time 137 Server 0 service finished
# server 0 queue is 0
# Time 140  Arrival Event of agent 31
# server 0 add element to local queue
# Time 141 Server 1 service finished
# server 1 queue is 0
# Time 145 Server 2 service finished
# server 2 queue is 0
# Time 145  Arrival Event of agent 32
# server 1 add element to local queue
# Time 147  Arrival Event of agent 33
# server 2 add element to local queue
# Time 149  Arrival Event of agent 34
# server 4 add element to local queue
# Time 150  Arrival Event of agent 35
# Server added
# server 0 add element to local queue
# Time 153 Server 3 service finished
# server 3 queue is 0
# Time 153  Arrival Event of agent 36
# server 3 add element to local queue
# Time 155 Server 0 service finished
# server 0 queue is 1
# Time 156  Arrival Event of agent 37
# server 0 add element to local queue
# Time 159 Server 1 service finished
# server 1 queue is 0
# Time 163  Arrival Event of agent 38
# server 1 add element to local queue
# Time 165 Server 2 service finished
# server 2 queue is 0
# Time 167 Server 0 service finished
# server 0 queue is 1
# Time 167  Arrival Event of agent 39
# server 2 add element to local queue
# Time 168 Server 4 service finished
# server 4 queue is 0
# Time 169 Server 3 service finished
# server 3 queue is 0
# Time 170 Server 0 service finished
# server 0 queue is 0
# Time 171  Arrival Event of agent 40
# Server removed
# server 0 add element to local queue
# Time 173  Arrival Event of agent 41
# server 3 add element to local queue
# Time 175  Arrival Event of agent 42
# Server added
# server 4 add element to local queue
# Time 177  Arrival Event of agent 43
# server 0 add element to local queue
# Time 179  Arrival Event of agent 44
# server 1 add element to local queue
# Time 180 Server 1 service finished
# server 1 queue is 1
# Time 183 Server 2 service finished
# server 2 queue is 0
# Time 183  Arrival Event of agent 45
# server 2 add element to local queue
# Time 186 Server 0 service finished
# server 0 queue is 1
# Time 189 Server 3 service finished
# server 3 queue is 0
# Time 189 Server 4 service finished
# server 4 queue is 0
# Time 189  Arrival Event of agent 46
# Server removed
# server 3 add element to local queue
# Time 190  Arrival Event of agent 47
# Server added
# server 4 add element to local queue
# Time 194 Server 1 service finished
# server 1 queue is 0
# Time 195 Server 0 service finished
# server 0 queue is 0
# Time 198  Arrival Event of agent 48
# Server removed
# server 0 add element to local queue
# Time 200 Server 2 service finished
# server 2 queue is 0
# Time 205 Server 3 service finished
# server 3 queue is 0
# Time 205  Arrival Event of agent 49
# server 1 add element to local queue
# Time 206 Server 4 service finished
# server 4 queue is 0
# Time 207  Arrival Event of agent 50
# server 2 add element to local queue
# Time 211  Arrival Event of agent 51
# server 3 add element to local queue
# Time 213  Arrival Event of agent 52
# server 4 add element to local queue
# Time 214 Server 0 service finished
# server 0 queue is 0
# Time 218  Arrival Event of agent 53
# server 0 add element to local queue
# Time 220 Server 1 service finished
# server 1 queue is 0
# Time 221  Arrival Event of agent 54
# Server added
# server 1 add element to local queue
# Time 226 Server 2 service finished
# server 2 queue is 0
# Time 227  Arrival Event of agent 55
# server 2 add element to local queue
# Time 228 Server 3 service finished
# server 3 queue is 0
# Time 231 Server 4 service finished
# server 4 queue is 0
# Time 232  Arrival Event of agent 56
# Server removed
# server 3 add element to local queue
# Time 236 Server 0 service finished
# server 0 queue is 0
# Time 237 Server 1 service finished
# server 1 queue is 0
# Time 237  Arrival Event of agent 57
# server 0 add element to local queue
# Time 241  Arrival Event of agent 58
# server 1 add element to local queue
# Time 245 Server 2 service finished
# server 2 queue is 0
# Time 246 Server 3 service finished
# server 3 queue is 0
# Time 246  Arrival Event of agent 59
# server 2 add element to local queue
# Time 252 Server 0 service finished
# server 0 queue is 0
# Time 253  Arrival Event of agent 60
# server 0 add element to local queue
# Time 255 Server 1 service finished
# server 1 queue is 0
# Time 259  Arrival Event of agent 61
# server 1 add element to local queue
# Time 262 Server 2 service finished
# server 2 queue is 0
# Time 265  Arrival Event of agent 62
# server 2 add element to local queue
# Time 269 Server 0 service finished
# server 0 queue is 0
# Time 273  Arrival Event of agent 63
# server 0 add element to local queue
# Time 274 Server 1 service finished
# server 1 queue is 0
# Time 279  Arrival Event of agent 64
# server 1 add element to local queue
# Time 280  Arrival Event of agent 65
# server 3 add element to local queue
# Time 282 Server 2 service finished
# server 2 queue is 0
# Time 285  Arrival Event of agent 66
# server 2 add element to local queue
# Time 289 Server 0 service finished
# server 0 queue is 0
# Time 289  Arrival Event of agent 67
# server 0 add element to local queue
# Time 294 Server 1 service finished
# server 1 queue is 0
# Time 296 Server 3 service finished
# server 3 queue is 0
# Time 296  Arrival Event of agent 68
# server 1 add element to local queue
# Time 300 Server 2 service finished
# server 2 queue is 0
# Time 303  Arrival Event of agent 69
# server 2 add element to local queue
# Time 306 Server 0 service finished
# server 0 queue is 0
# Time 310 Server 1 service finished
# server 1 queue is 0
# Time 310  Arrival Event of agent 70
# server 0 add element to local queue
# Time 317  Arrival Event of agent 71
# server 1 add element to local queue
# Time 322 Server 2 service finished
# server 2 queue is 0
# Time 325  Arrival Event of agent 72
# server 2 add element to local queue
# Time 327 Server 0 service finished
# server 0 queue is 0
# Time 331  Arrival Event of agent 73
# server 0 add element to local queue
# Time 332 Server 1 service finished
# server 1 queue is 0
# Time 333  Arrival Event of agent 74
# server 1 add element to local queue
# Time 337  Arrival Event of agent 75
# server 3 add element to local queue
# Time 339 Server 2 service finished
# server 2 queue is 0
# Time 344  Arrival Event of agent 76
# server 2 add element to local queue
# Time 347  Arrival Event of agent 77
# Server added
# server 4 add element to local queue
# Time 348 Server 0 service finished
# server 0 queue is 0
# Time 350 Server 1 service finished
# server 1 queue is 0
# Time 353  Arrival Event of agent 78
# Server removed
# server 0 add element to local queue
# Time 354 Server 3 service finished
# server 3 queue is 0
# Time 356  Arrival Event of agent 79
# server 1 add element to local queue
# Time 361 Server 2 service finished
# server 2 queue is 0
# Time 361 Server 4 service finished
# server 4 queue is 0
# Time 362  Arrival Event of agent 80
# server 2 add element to local queue
# Time 369 Server 0 service finished
# server 0 queue is 0
# Time 369  Arrival Event of agent 81
# server 0 add element to local queue
# Time 371 Server 1 service finished
# server 1 queue is 0
# Time 376  Arrival Event of agent 82
# server 1 add element to local queue
# Time 378  Arrival Event of agent 83
# server 3 add element to local queue
# Time 380 Server 2 service finished
# server 2 queue is 0
# Time 380  Arrival Event of agent 84
# server 2 add element to local queue
# Time 386 Server 0 service finished
# server 0 queue is 0
# Time 386  Arrival Event of agent 85
# server 0 add element to local queue
# Time 392 Server 1 service finished
# server 1 queue is 0
# Time 392 Server 3 service finished
# server 3 queue is 0
# Time 394  Arrival Event of agent 86
# server 1 add element to local queue
# Time 396 Server 2 service finished
# server 2 queue is 0
# Time 399  Arrival Event of agent 87
# server 2 add element to local queue
# Time 400  Arrival Event of agent 88
# server 3 add element to local queue
# Time 402 Server 0 service finished
# server 0 queue is 0
# Time 404  Arrival Event of agent 89
# server 0 add element to local queue
# Time 408  Arrival Event of agent 90
# server 4 add element to local queue
# Time 411 Server 1 service finished
# server 1 queue is 0
# Time 413  Arrival Event of agent 91
# Server added
# server 1 add element to local queue
# Time 415  Arrival Event of agent 92
# server 0 add element to local queue
# Time 416 Server 2 service finished
# server 2 queue is 0
# Time 418 Server 3 service finished
# server 3 queue is 0
# Time 420 Server 0 service finished
# server 0 queue is 1
# Time 422  Arrival Event of agent 93
# Server removed
# server 2 add element to local queue
# Time 423 Server 4 service finished
# server 4 queue is 0
# Time 425  Arrival Event of agent 94
# server 3 add element to local queue
# Time 428  Arrival Event of agent 95
# server 4 add element to local queue
# Time 430 Server 1 service finished
# server 1 queue is 0
# Time 432 Server 0 service finished
# server 0 queue is 0
# Time 433  Arrival Event of agent 96
# server 0 add element to local queue
# Time 438 Server 2 service finished
# server 2 queue is 0
# Time 440  Arrival Event of agent 97
# server 1 add element to local queue
# Time 442 Server 3 service finished
# server 3 queue is 0
# Time 442  Arrival Event of agent 98
# server 2 add element to local queue
# Time 443  Arrival Event of agent 99
# Server added
# server 3 add element to local queue
# Time 444 Server 4 service finished
# server 4 queue is 0
# Time 449 Server 0 service finished
# server 0 queue is 0
# Time 456 Server 1 service finished
# server 1 queue is 0
# Time 456 Server 2 service finished
# server 2 queue is 0
# Time 458 Server 3 service finished
# server 3 queue is 0
# All time: 458.0
#
# Average waiting time: 0.43
#
# Probability that a customer has to wait: 0.07
#
# Probability of an Idle server: -2.42
#
# Average service time: 16.08
#
# Average time between arrivals: 4.47
#
# Average waiting time for those who wait: 6.14
#
# Average time a customer spends in the system: 16.08
#
# Average time a customer spends in the system (alternative): 16.51

# %%
print(total_time)
print(avg_queue_time)
print(waited_custs)
print(server_dynamic)
# Out:
# {'General queue': 476.0, 'Shortest queue': 469.0, 'Dynamic g queue': 439.0, 'Dynamic Shortest': 458.0}
# {'General queue': 0.87, 'Shortest queue': 1.62, 'Dynamic g queue': 0.21, 'Dynamic Shortest': 0.43}
# {'General queue': 24, 'Shortest queue': 21, 'Dynamic g queue': 6, 'Dynamic Shortest': 7}
# {'Dynamic g queue': [(16.0, 3), (20.0, 3), (25.0, 5), (30.0, 5), (33.0, 5), (34.0, 5), (34.0, 4), (39.0, 4), (42.0, 4), (47.0, 4), (47.0, 3), (51.0, 2), (53.0, 2), (55.0, 2), (59.0, 3), (65.0, 3), (72.0, 2), (73.0, 2), (80.0, 2), (87.0, 3), (95.0, 3), (95.0, 2), (99.0, 1), (107.0, 2), (115.0, 3), (117.0, 2), (123.0, 2), (126.0, 2), (129.0, 3), (131.0, 3), (141.0, 5), (142.0, 5), (144.0, 4), (149.0, 3), (150.0, 3), (151.0, 3), (156.0, 3), (157.0, 3), (166.0, 3), (167.0, 3), (171.0, 2), (175.0, 3), (180.0, 3), (188.0, 3), (189.0, 2), (196.0, 3), (199.0, 3), (202.0, 3), (205.0, 3), (209.0, 3), (217.0, 3), (220.0, 2), (223.0, 2), (231.0, 3), (232.0, 3), (239.0, 3), (240.0, 2), (245.0, 2), (252.0, 3), (257.0, 3), (265.0, 3), (266.0, 2), (269.0, 2), (275.0, 2), (279.0, 3), (282.0, 3), (286.0, 3), (292.0, 3), (294.0, 2), (302.0, 3), (307.0, 3), (313.0, 3), (314.0, 2), (321.0, 2), (327.0, 2), (334.0, 3), (341.0, 4), (342.0, 3), (347.0, 3), (348.0, 4), (355.0, 3), (355.0, 3), (360.0, 4), (361.0, 3), (363.0, 2), (371.0, 2), (373.0, 2), (376.0, 3), (381.0, 2), (382.0, 2), (388.0, 1), (398.0, 3), (405.0, 3), (407.0, 3), (414.0, 2), (416.0, 2), (422.0, 2), (430.0, 2), (430.0, 1), (439.0, 0)], 'Dynamic Shortest': [(16.0, 3), (22.0, 3), (23.0, 2), (27.0, 2), (33.0, 1), (41.0, 2), (47.0, 2), (54.0, 3), (58.0, 3), (66.0, 5), (66.0, 4), (74.0, 4), (78.0, 3), (79.0, 3), (80.0, 2), (85.0, 2), (94.0, 3), (96.0, 3), (104.0, 3), (108.0, 3), (111.0, 3), (117.0, 4), (122.0, 4), (125.0, 3), (130.0, 3), (132.0, 4), (133.0, 3), (137.0, 2), (141.0, 2), (145.0, 1), (153.0, 4), (155.0, 5), (159.0, 4), (165.0, 4), (167.0, 4), (168.0, 4), (169.0, 3), (170.0, 2), (180.0, 5), (183.0, 4), (186.0, 5), (189.0, 4), (189.0, 3), (194.0, 4), (195.0, 3), (200.0, 3), (205.0, 2), (206.0, 1), (214.0, 3), (220.0, 4), (226.0, 4), (228.0, 4), (231.0, 3), (236.0, 3), (237.0, 2), (245.0, 3), (246.0, 2), (252.0, 2), (255.0, 2), (262.0, 2), (269.0, 2), (274.0, 2), (282.0, 3), (289.0, 3), (294.0, 3), (296.0, 2), (300.0, 2), (306.0, 2), (310.0, 1), (322.0, 2), (327.0, 2), (332.0, 2), (339.0, 3), (348.0, 4), (350.0, 3), (354.0, 3), (361.0, 2), (361.0, 1), (369.0, 1), (371.0, 2), (380.0, 2), (386.0, 2), (392.0, 3), (392.0, 2), (396.0, 1), (402.0, 2), (411.0, 4), (416.0, 4), (418.0, 3), (420.0, 3), (423.0, 3), (430.0, 3), (432.0, 2), (438.0, 2), (442.0, 3), (444.0, 4), (449.0, 3), (456.0, 2), (456.0, 1), (458.0, 0)]}

# %%
from tabulate import tabulate

data = []
for key, value in total_time.items():
    data.append([key]+[total_time[key]] + [avg_queue_time[key]] + [waited_custs[key]])

col_names = ["Queue type", "Total time", "Avg. queue time", "Waited custs"]

print(tabulate(data, headers=col_names, tablefmt="fancy_grid"))
# Out:
# ╒══════════════════╤══════════════╤═══════════════════╤════════════════╕
# │ Queue type       │   Total time │   Avg. queue time │   Waited custs │
# ╞══════════════════╪══════════════╪═══════════════════╪════════════════╡
# │ General queue    │          476 │              0.87 │             24 │
# ├──────────────────┼──────────────┼───────────────────┼────────────────┤
# │ Shortest queue   │          469 │              1.62 │             21 │
# ├──────────────────┼──────────────┼───────────────────┼────────────────┤
# │ Dynamic g queue  │          439 │              0.21 │              6 │
# ├──────────────────┼──────────────┼───────────────────┼────────────────┤
# │ Dynamic Shortest │          458 │              0.43 │              7 │
# ╘══════════════════╧══════════════╧═══════════════════╧════════════════╛

# %%
fig = plt.figure(figsize=(18, 9))
count = 1
colors = ["red", "tab:blue", "tab:orange"]


for key, value in server_dynamic.items():
    x_data, y_data = [item[0] for item in server_dynamic[key]], [item[1] for item in server_dynamic[key]]
    plt.subplot(1,2,count)
    plt.hist(y_data, bins=6, label = f"{key}", color = colors[count])
    count += 1

    plt.title("Server dynamic", color = 'w')
    plt.grid()
    plt.tick_params( colors='white')
    plt.legend(loc='best')

plt.show()

# %%
fig = plt.figure(figsize=(18, 9))

for key, value in server_dynamic.items():
    x_data, y_data = [item[0] for item in server_dynamic[key]], [item[1] for item in server_dynamic[key]]
    plt.plot(x_data, y_data, label = f"{key}")

plt.title("Server dynamic", color = 'w')
plt.grid()
plt.tick_params( colors='white')
plt.legend(loc='best')
plt.show()

# %%
def DrawSampleHistogram(R, title, bins=None):
    fig = plt.figure()
    x = np.arange(len(R))
    plt.grid()
    if bins is None:
        plt.hist(R, range=None)
    else:
        plt.hist(R, bins=bins, range=None)

    plt.xticks(rotation='horizontal')
    plt.tick_params( colors='white')
    plt.title(title, color='white')
    plt.show()


DrawSampleHistogram([x.waitingTimeInQueue for x in DEVS.stats], "Waiting time in queue")
